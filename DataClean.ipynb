# %%
import pandas as pd

df = pd.read_csv('Amazon.csv')
print(df.head)
# Out:
# <bound method NDFrame.head of       product_id                                       product_name  \
# 0     B002PD61Y4  D-Link DWA-131 300 Mbps Wireless Nano USB Adap...
# 1     B002PD61Y4  D-Link DWA-131 300 Mbps Wireless Nano USB Adap...
# 2     B002SZEOLG  TP-Link Nano USB WiFi Dongle 150Mbps High Gain...
# 3     B003B00484  Duracell Plus AAA Rechargeable Batteries (750 ...
# 4     B003L62T7W  Logitech B100 Wired USB Mouse, 3 yr Warranty, ...
# ...          ...                                                ...
# 1460  B0BPCJM7TB  WIDEWINGS Electric Handheld Milk Wand Mixer Fr...
# 1461  B0BPJBTB3F  Khaitan ORFin Fan heater for Home and kitchen-...
# 1462  B0BQ3K23Y1  Oratech Coffee Frother electric, milk frother ...
# 1463  B0BQRJ3C47  REDTECH USB-C to Lightning Cable 3.3FT, [Apple...
# 1464  B0BR4F878Q  Swiffer Instant Electric Water Heater Faucet T...
#
#                                                category discounted_price  \
# ...

# %%
Data=pd.DataFrame(df)
print(Data)
# Out:
#       product_id                                       product_name  \
# 0     B002PD61Y4  D-Link DWA-131 300 Mbps Wireless Nano USB Adap...
# 1     B002PD61Y4  D-Link DWA-131 300 Mbps Wireless Nano USB Adap...
# 2     B002SZEOLG  TP-Link Nano USB WiFi Dongle 150Mbps High Gain...
# 3     B003B00484  Duracell Plus AAA Rechargeable Batteries (750 ...
# 4     B003L62T7W  Logitech B100 Wired USB Mouse, 3 yr Warranty, ...
# ...          ...                                                ...
# 1460  B0BPCJM7TB  WIDEWINGS Electric Handheld Milk Wand Mixer Fr...
# 1461  B0BPJBTB3F  Khaitan ORFin Fan heater for Home and kitchen-...
# 1462  B0BQ3K23Y1  Oratech Coffee Frother electric, milk frother ...
# 1463  B0BQRJ3C47  REDTECH USB-C to Lightning Cable 3.3FT, [Apple...
# 1464  B0BR4F878Q  Swiffer Instant Electric Water Heater Faucet T...
#
#                                                category discounted_price  \
# 0     Computers&Accessories|NetworkingDevices|Networ...             ₹507
# ...
